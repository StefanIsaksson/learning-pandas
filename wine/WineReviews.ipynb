# %%
import pandas as pd
reviews = pd.read_csv("data/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews.head(5)
# Out:
#          country                                        description  \
# serial
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
#
#                                designation  points  price           province  \
# serial
# 0                             Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                 Avidagos      87   15.0              Douro
# 2                                      NaN      87   14.0             Oregon
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                    region_1           region_2         taster_name  \
# ...

# %%
reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %% [markdown]
# retrivies first 6 rows, and first column, using **label-based** selection

# %%
reviews.loc[0:5,'country']
# Out:
# serial
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# 5       Spain
# Name: country, dtype: object

# %% [markdown]
# retrivies first 6 rows, and first column, using **index-based** selection

# %%
reviews.iloc[0:6,0]
# Out:
# serial
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# 5       Spain
# Name: country, dtype: object

# %%
reviews.loc[:5, ['country', 'title', 'points']]
# Out:
#          country                                              title  points
# serial
# 0          Italy                  Nicosia 2013 Vulkà Bianco  (Etna)      87
# 1       Portugal      Quinta dos Avidagos 2011 Avidagos Red (Douro)      87
# 2             US      Rainstorm 2013 Pinot Gris (Willamette Valley)      87
# 3             US  St. Julian 2013 Reserve Late Harvest Riesling ...      87
# 4             US  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      87
# 5          Spain  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...      87

# %% [markdown]
# Change index to title column

# %%
reviews.set_index('title')
# Out:
#                                                         country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                         Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)          Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                US
# St. Julian 2013 Reserve Late Harvest Riesling (...           US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...        Spain
# Terre di Giurfo 2013 Belsito Frappato (Vittoria)          Italy
# Trimbach 2012 Gewurztraminer (Alsace)                    France
# Heinz Eifel 2013 Shine Gewürztraminer (Rheinhes...      Germany
# Jean-Baptiste Adam 2012 Les Natures Pinot Gris ...       France
# Kirkland Signature 2011 Mountain Cuvée Cabernet...           US
# Leon Beyer 2012 Gewurztraminer (Alsace)                  France
# Louis M. Martini 2012 Cabernet Sauvignon (Alexa...           US
# ...

# %% [markdown]
# Lists all columns

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# Operation returns Series of True/False booleans based on if country for record is Germany

# %%
reviews.country == 'Germany'
# Out:
# serial
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8          True
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15         True
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 129941    False
# 129942    False
# 129943    False
# 129944    False
# 129945    False
# 129946     True
# 129947    False
# 129948    False
# 129949    False
# 129950    False
# 129951    False
# 129952    False
# 129953    False
# 129954    False
# 129955    False
# 129956    False
# 129957    False
# 129958    False
# 129959    False
# 129960    False
# 129961    False
# 129962    False
# 129963    False
# 129964    False
# ...

# %% [markdown]
# Select wines from germany

# %%
reviews.loc[reviews.country == 'Germany']
# Out:
#         country                                        description  \
# serial
# 8       Germany  Savory dried thyme notes accent sunnier flavor...
# 15      Germany  Zesty orange peels and apple notes abound in t...
# 76      Germany  Earthy pollen and mineral notes lend a savory ...
# 85      Germany  Pronounced dust, pollen and earth tones lend s...
# 148     Germany  Crisp, pristine peach and apricot notes resona...
# 156     Germany  Approachably fruity yet nuanced and electrifyi...
# 170     Germany  Fresh and fragrant of blossoms, tart yellow pe...
# 171     Germany  Just a touch of honey-lemon sweetness is enoug...
# 347     Germany  Dusty, saffron-spiced earthiness is juxtaposed...
# 354     Germany  Whiffs of white mushroom, saffron and caramel ...
# 358     Germany  Intensely fragrant, this honey-sweet auslese w...
# 464     Germany  Richly textured and unabashedly full in body, ...
# 468     Germany  The nose of this powerfully fruity yet dry Rie...
# ...

# %% [markdown]
# Select wines made in Germany **and** which is rated with 90 or more.

# %%
reviews.loc[(reviews.country == 'Germany') & (reviews.points >= 90)]
# Out:
#         country                                        description  \
# serial
# 148     Germany  Crisp, pristine peach and apricot notes resona...
# 156     Germany  Approachably fruity yet nuanced and electrifyi...
# 170     Germany  Fresh and fragrant of blossoms, tart yellow pe...
# 171     Germany  Just a touch of honey-lemon sweetness is enoug...
# 347     Germany  Dusty, saffron-spiced earthiness is juxtaposed...
# 354     Germany  Whiffs of white mushroom, saffron and caramel ...
# 358     Germany  Intensely fragrant, this honey-sweet auslese w...
# 464     Germany  Richly textured and unabashedly full in body, ...
# 468     Germany  The nose of this powerfully fruity yet dry Rie...
# 469     Germany  Lanolin and honeycomb notes lend a minerally f...
# 527     Germany  A surprising whiff of black currant on the nos...
# 535     Germany  Fresh green apple and grapefruit aromas are bo...
# 648     Germany  A spray of rose petals perfumes this aromatic ...
# ...

# %% [markdown]
# Select wines made in Germany **or** which is rated with 90 or more.

# %%
reviews.loc[(reviews.country == 'Germany') | (reviews.points >= 90)]
# Out:
#              country                                        description  \
# serial
# 8            Germany  Savory dried thyme notes accent sunnier flavor...
# 15           Germany  Zesty orange peels and apple notes abound in t...
# 76           Germany  Earthy pollen and mineral notes lend a savory ...
# 85           Germany  Pronounced dust, pollen and earth tones lend s...
# 119           France  Medium-gold in color. Complex and inviting nos...
# 120            Italy  Slightly backward, particularly given the vint...
# 121               US  The vineyard is one of the better Chardonnay s...
# 122               US  Defines Rockpile Zinfandel in intensity of fru...
# 123        Australia  The blend is roughly two-thirds Shiraz and one...
# 124               US  This sophisticated wine is mostly Cabernet Sau...
# 125     South Africa  Etienne Le Riche is a total Cabernet specialis...
# 126           France  Mid-gold color. Pronounced and enticing aromas...
# ...

# %% [markdown]
# Select wines from Italy or France using Panda conditional **isin**

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# serial
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26       Italy  Pretty aromas of yellow flower and stone fruit...
# 27       Italy  Aromas recall ripe dark berry, toast and a whi...
# 28       Italy  Aromas suggest mature berry, scorched earth, a...
# 30      France  Red cherry fruit comes laced with light tannin...
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# ...

# %% [markdown]
# Select wines with prices using Panda conditional **isnull**

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#             country                                        description  \
# serial
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# 12               US  Slightly reduced, this wine offers a chalky, t...
# ...

# %% [markdown]
# Assigning data

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# serial
# 0         everyone
# 1         everyone
# 2         everyone
# 3         everyone
# 4         everyone
# 5         everyone
# 6         everyone
# 7         everyone
# 8         everyone
# 9         everyone
# 10        everyone
# 11        everyone
# 12        everyone
# 13        everyone
# 14        everyone
# 15        everyone
# 16        everyone
# 17        everyone
# 18        everyone
# 19        everyone
# 20        everyone
# 21        everyone
# 22        everyone
# 23        everyone
# 24        everyone
# 25        everyone
# 26        everyone
# 27        everyone
# 28        everyone
# 29        everyone
#             ...
# 129941    everyone
# 129942    everyone
# 129943    everyone
# 129944    everyone
# 129945    everyone
# 129946    everyone
# 129947    everyone
# 129948    everyone
# 129949    everyone
# 129950    everyone
# 129951    everyone
# 129952    everyone
# 129953    everyone
# 129954    everyone
# 129955    everyone
# 129956    everyone
# ...

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# serial
# 0         129971
# 1         129970
# 2         129969
# 3         129968
# 4         129967
# 5         129966
# 6         129965
# 7         129964
# 8         129963
# 9         129962
# 10        129961
# 11        129960
# 12        129959
# 13        129958
# 14        129957
# 15        129956
# 16        129955
# 17        129954
# 18        129953
# 19        129952
# 20        129951
# 21        129950
# 22        129949
# 23        129948
# 24        129947
# 25        129946
# 26        129945
# 27        129944
# 28        129943
# 29        129942
#            ...
# 129941        30
# 129942        29
# 129943        28
# 129944        27
# 129945        26
# 129946        25
# 129947        24
# 129948        23
# 129949        22
# 129950        21
# 129951        20
# 129952        19
# 129953        18
# 129954        17
# 129955        16
# 129956        15
# 129957        14
# 129958        13
# 129959        12
# 129960        11
# 129961        10
# ...

# %%
reviews.head(5)
# Out:
#          country                                        description  \
# serial
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
#
#                                designation  points  price           province  \
# serial
# 0                             Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                 Avidagos      87   15.0              Douro
# 2                                      NaN      87   14.0             Oregon
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                    region_1           region_2         taster_name  \
# ...

# %% [markdown]
# Panda summary functions

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews.country.describe()
# Out:
# count     129908
# unique        43
# top           US
# freq       54504
# Name: country, dtype: object

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
reviews.country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# Map takes one set of values and "maps" them to another set of values.

# %%
review_points_min = reviews.points.min()

# %%
new_point_scale = reviews.points.map(lambda p: (p - review_points_min)/2)

# %%
new_point_scale.describe()
# Out:
# count    129971.000000
# mean          4.223569
# std           1.519865
# min           0.000000
# 25%           3.000000
# 50%           4.000000
# 75%           5.500000
# max          10.000000
# Name: points, dtype: float64

# %% [markdown]
# Dataframe.apply calls a custom method on each row.

# %%
def rescale_points(row):
    row.points = (row.points - review_points_min)/2
    return row

reviews.apply(rescale_points, axis='columns')
# Out:
#             country                                        description  \
# serial
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
reviews.points - reviews.points.mean()
# Out:
# serial
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
# 5        -1.447138
# 6        -1.447138
# 7        -1.447138
# 8        -1.447138
# 9        -1.447138
# 10       -1.447138
# 11       -1.447138
# 12       -1.447138
# 13       -1.447138
# 14       -1.447138
# 15       -1.447138
# 16       -1.447138
# 17       -1.447138
# 18       -1.447138
# 19       -1.447138
# 20       -1.447138
# 21       -1.447138
# 22       -1.447138
# 23       -1.447138
# 24       -1.447138
# 25       -1.447138
# 26       -1.447138
# 27       -1.447138
# 28       -1.447138
# 29       -2.447138
#             ...
# 129941    1.552862
# 129942    1.552862
# 129943    1.552862
# 129944    1.552862
# 129945    1.552862
# 129946    1.552862
# 129947    1.552862
# 129948    1.552862
# 129949    1.552862
# 129950    1.552862
# 129951    1.552862
# 129952    1.552862
# 129953    1.552862
# 129954    1.552862
# 129955    1.552862
# 129956    1.552862
# ...

# %%
reviews
# Out:
#             country                                        description  \
# serial
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
reviews.country + " - " + reviews.region_1
# Out:
# serial
# 0                          Italy - Etna
# 1                                   NaN
# 2                US - Willamette Valley
# 3              US - Lake Michigan Shore
# 4                US - Willamette Valley
# 5                       Spain - Navarra
# 6                      Italy - Vittoria
# 7                       France - Alsace
# 8                                   NaN
# 9                       France - Alsace
# 10                     US - Napa Valley
# 11                      France - Alsace
# 12                US - Alexander Valley
# 13                         Italy - Etna
# 14                   US - Central Coast
# 15                                  NaN
# 16                 Argentina - Cafayate
# 17                  Argentina - Mendoza
# 18             Spain - Ribera del Duero
# 19                        US - Virginia
# 20                        US - Virginia
# 21                          US - Oregon
# 22                      Italy - Sicilia
# ...

# %%
n_trop = reviews.description.map(lambda desc: "fishy" in desc).sum()
n_rotten = reviews.description.map(lambda desc: "rotten" in desc).sum()
descriptor_counts = pd.Series([n_trop, n_fruity], index=['fishy', 'rotten'])
print(descriptor_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-92a6e239beea> in <module>()
#       1 n_trop = reviews.description.map(lambda desc: "fishy" in desc).sum()
#       2 n_rotten = reviews.description.map(lambda desc: "rotten" in desc).sum()
# ----> 3 descriptor_counts = pd.Series([n_trop, n_fruity], index=['fishy', 'rotten'])
#       4 print(descriptor_counts)
#
# NameError: name 'n_fruity' is not defined

# %%
reviews[reviews.description.map(lambda desc: "rotten" in desc)]

# %%
reviews[reviews.description.map(lambda desc: "fishy" in desc)]

# %%
def create_star_rating(row):
    if row.points >= 95 or row.country == 'Germany':
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1

star_ratings = reviews.apply(create_star_rating, axis='columns')

reviews['stars'] = star_ratings

reviews

# %% [markdown]
# # Grouping

# %%
reviews.groupby('points').points.count()

# %% [markdown]
# Code above gives the same result as:

# %%
reviews.points.value_counts()

# %%
reviews.groupby('country').points.median()

# %%
reviews.groupby('country').apply(lambda df: f'count: {df.points.count()}, median: {df.points.median()}, min: {df.points.min()}, max: {df.points.max()}')

# %%
reviews.groupby(['country']).price.agg([len, min, max])

# %% [markdown]
# Find best wine by country and provice

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])

# %% [markdown]
# ## Multi-index

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed

# %%
type(countries_reviewed.index)

# %%
type(reviews.index)

# %% [markdown]
# Change from MultiIndex to regular index

# %%
countries_reviewed = countries_reviewed.reset_index()

# %% [markdown]
# Find wine provinces in Germany

# %%
countries_reviewed[countries_reviewed.country == 'Germany']

# %% [markdown]
# Sort by number of wine reviews

# %%
countries_reviewed.sort_values(by='len', ascending=False)

# %%
countries_reviewed.sort_values(by=['country', 'len'], ascending=False)

# %%
reviews[reviews.country == 'Germany'].groupby(['country','variety']).description.agg([len]).sort_values(by='len', ascending=False)

# %%
reviews[((reviews.province == 'Franken') & (reviews.variety == 'Riesling'))]

# %%
reviews[reviews.country.isnull()]

# %%
reviews.region_2.fillna("Unknown")

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")

# %%
reviews.rename(columns={'points': 'score'})

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})

# %%
reviews.rename_axis("wines", axis='rows')

# %%
reviews.rename_axis("fields", axis='columns')

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')

# %% [markdown]
# # Visualisation
#
# ## Bar charts
#
# Plotting with absolute numbers:

# %%
% matplotlib inline

# %%
reviews['province'].value_counts().head(10).plot.bar()

# %% [markdown]
# Relative numbers

# %%
(reviews['province'].value_counts().head(10) / len(reviews)).plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %% [markdown]
# ## Line charts

# %%
reviews['points'].value_counts().sort_index().plot.line()

# %% [markdown]
# ## Area charts (line charts, but with the bottom shaded in)

# %%
reviews['points'].value_counts().sort_index().plot.area()

# %% [markdown]
# ## Histograms
#
# Each bar represents a range of values.

# %%
reviews[reviews['price'] < 200]['price'].plot.hist()

# %% [markdown]
# ## Scatter plot

# %%
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price', y='points')

# %% [markdown]
# ## Hexplot

# %%
reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# %%
germany_score = reviews[reviews.country == 'Germany'].groupby(['points']).points.count()

# %%
germany_score.plot.bar()

# %%
france_score = reviews[reviews.country == 'France'].groupby(['points']).points.count()

# %%
france_score.plot.bar()

# %%
combined_country_score = pd.DataFrame(
    {'Germany': germany_score, 
     'France' : france_score}
)

# %%
combined_country_score
# Out:
#         Germany  France
# points
# 80          NaN      15
# 81          1.0      36
# 82          2.0     107
# 83          2.0     301
# 84         17.0    1088
# 85         47.0    1709
# 86        116.0    2024
# 87        199.0    2594
# 88        254.0    2898
# 89        309.0    2129
# 90        410.0    2538
# 91        272.0    2030
# 92        207.0    1710
# 93        170.0    1393
# 94         94.0     856
# 95         39.0     413
# 96         17.0     145
# 97          8.0      70
# 98          1.0      21
# 99          NaN       8
# 100         NaN       8

# %% [markdown]
# ## Stacked plots

# %%
combined_country_score.plot.bar(stacked=True)

# %%
combined_country_score_relative = combined_country_score.copy()
combined_country_score_relative.France = combined_country_score_relative.France / combined_country_score_relative.France.sum()
combined_country_score_relative.Germany = combined_country_score_relative.Germany / combined_country_score_relative.Germany.sum()

# %%
combined_country_score_relative
# Out:
#          Germany    France
# points
# 80           NaN  0.000679
# 81      0.000462  0.001629
# 82      0.000924  0.004843
# 83      0.000924  0.013624
# 84      0.007852  0.049246
# 85      0.021709  0.077355
# 86      0.053580  0.091613
# 87      0.091917  0.117413
# 88      0.117321  0.131173
# 89      0.142725  0.096365
# 90      0.189376  0.114878
# 91      0.125635  0.091884
# 92      0.095612  0.077400
# 93      0.078522  0.063052
# 94      0.043418  0.038745
# 95      0.018014  0.018694
# 96      0.007852  0.006563
# 97      0.003695  0.003168
# 98      0.000462  0.000951
# 99           NaN  0.000362
# 100          NaN  0.000362

# %%
combined_country_score_relative.plot.bar(stacked=True)

# %%
combined_country_score_relative.plot.area()

# %% [markdown]
# ## Bivariate line chart

# %%
combined_country_score_relative.plot.line()

# %% [markdown]
# ## Styling plots
#
# figsize controls size of the image, expects a tupe of (width and height)

# %%
reviews['points'].value_counts().sort_index().plot.bar(figsize=(12, 6))

# %% [markdown]
# change color, css colors are available:
# https://www.w3schools.com/cssref/css_colors.asp

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='crimson'
)

# %% [markdown]
# change font size

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='crimson',
    fontsize=16
)

# %% [markdown]
# Adding a title

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='crimson',
    fontsize=16,
    title='Rankings Given by Wine Magazine',
)

# %% [markdown]
# Increasing fontsize on title using underlying library matplotlib

# %%
import matplotlib.pyplot as plt

ax = reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='crimson',
    fontsize=16
)
ax.set_title("Rankings Given by Wine Magazine", fontsize=20)
# Out:
# Text(0.5,1,'Rankings Given by Wine Magazine')

# %% [markdown]
# Turn off black border using seaborn (which also is using matplotlib)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ax = reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='crimson',
    fontsize=16
)
ax.set_title("Rankings Given by Wine Magazine", fontsize=20)
sns.despine(bottom=True, left=True)

# %% [markdown]
# ## Subplots
#
# creating multiple plots that live side-by-side in one overall figure.
# subplot method takes two arguments:
# - number of rows
# - number of columns.

# %%
fig, axarr = plt.subplots(2, 1, figsize=(12, 8))

# %%
fig, axarr = plt.subplots(2, 1, figsize=(12, 8))

reviews['points'].value_counts().sort_index().plot.bar(
    ax=axarr[0]
)

reviews['province'].value_counts().head(20).plot.bar(
    ax=axarr[1]
)

# %% [markdown]
# Creating a figure with room for four subplots

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

# %%
axarr
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000207148FDBE0>,
# ...
#       dtype=object)

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

reviews['points'].value_counts().sort_index().plot.bar(
    ax=axarr[0][0]
)

reviews['province'].value_counts().head(20).plot.bar(
    ax=axarr[1][1]
)

# %% [markdown]
# Styling subplot

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

reviews['points'].value_counts().sort_index().plot.bar(
    ax=axarr[0][0], fontsize=12, color='mediumvioletred'
)
axarr[0][0].set_title("Wine Scores", fontsize=18)

reviews['variety'].value_counts().head(20).plot.bar(
    ax=axarr[1][0], fontsize=12, color='mediumvioletred'
)
axarr[1][0].set_title("Wine Varieties", fontsize=18)

reviews['province'].value_counts().head(20).plot.bar(
    ax=axarr[1][1], fontsize=12, color='mediumvioletred'
)
axarr[1][1].set_title("Wine Origins", fontsize=18)

reviews['price'].value_counts().plot.hist(
    ax=axarr[0][1], fontsize=12, color='mediumvioletred'
)
axarr[0][1].set_title("Wine Prices", fontsize=18)

plt.subplots_adjust(hspace=.3)

import seaborn as sns
sns.despine()

# %% [markdown]
# # Seaborn
#
# ## Countplot
# (pandas bar becomes a seaborn countplot)

# %%
sns.countplot(reviews['points'])

# %% [markdown]
# Using seaborn countplot (as oppose to Pandas bar) we do not need to call value_counts

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %% [markdown]
# KDE Plot
#
# Seaborn does not have line or area chart, instead a package names kdeplot.
#
# KDE, short for "kernel density estimate".

# %%
sns.kdeplot(reviews[reviews.price < 200]['price'])

# %% [markdown]
# Panda line plot on same data for comparison:

# %%
reviews[reviews['price'] < 200]['price'].value_counts().sort_index().plot.line()

# %% [markdown]
# ## Two dimension KDE plot

# %%
kde_reviews = reviews[reviews['price'] < 200].loc[:, ['price', 'points']].dropna().sample(5000)

sns.kdeplot(kde_reviews['price'], kde_reviews['points'])

# %% [markdown]
# Panda scatter plot for comparison

# %%
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price', y='points')

# %% [markdown]
# Panda hex plot for comparison

# %%
reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# %% [markdown]
# ## Distplot
# Seaborn equivalent to pandas histogram

# %%
sns.distplot(reviews['points'], bins=10, kde=False)
# Out:
# C:\Users\Snigel\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Boxplot

# %%
top_5_variety = reviews.variety.value_counts().head(5).index

df = reviews[reviews.variety.isin(top_5_variety)]


sns.boxplot(
    x='variety',
    y='points',
    data=df
)

# %%
reviews.variety.value_counts().head(5).index
# Out:
# Index(['Pinot Noir', 'Chardonnay', 'Cabernet Sauvignon', 'Red Blend',
#        'Bordeaux-style Red Blend'],
#       dtype='object')

# %% [markdown]
# ## Violin plot

# %%
top_5_variety = reviews.variety.value_counts().head(5).index

df = reviews[reviews.variety.isin(top_5_variety)]


sns.violinplot(
    x='variety',
    y='points',
    data=df
)
